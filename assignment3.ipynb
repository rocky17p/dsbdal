# %%
import pandas as pd

# %%
iris=pd.read_csv('Iris.csv')

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.value_counts(iris["Species"])
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
stats=iris.groupby("Species")

# %%
stats.describe()
# Out:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
stats.mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
stats.median()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
stats["SepalLengthCm"].max()
# Out:
# Species
# Iris-setosa        5.8
# Iris-versicolor    7.0
# Iris-virginica     7.9
# Name: SepalLengthCm, dtype: float64

# %%
stats["PetalLengthCm"].min()
# Out:
# Species
# Iris-setosa        1.0
# Iris-versicolor    3.0
# Iris-virginica     4.5
# Name: PetalLengthCm, dtype: float64

# %%
iris_setosa=iris[iris["Species"]=="Iris-setosa"].drop(columns=["Species"])

# %%
iris_setosa.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
iris_setosa.quantile(0.25)
# Out:
# Id               13.250
# SepalLengthCm     4.800
# SepalWidthCm      3.125
# PetalLengthCm     1.400
# PetalWidthCm      0.200
# Name: 0.25, dtype: float64

# %%
iris_setosa.quantile(0.31)
# Out:
# Id               16.190
# SepalLengthCm     4.819
# SepalWidthCm      3.200
# PetalLengthCm     1.400
# PetalWidthCm      0.200
# Name: 0.31, dtype: float64

# %%
iris_versicolor=iris[iris["Species"]=="Iris-versicolor"].drop(columns=["Species"])

# %%
iris_versicolor.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
iris_versicolor.min()
# Out:
# Id               51.0
# SepalLengthCm     4.9
# SepalWidthCm      2.0
# PetalLengthCm     3.0
# PetalWidthCm      1.0
# dtype: float64

# %%
iris_versicolor.quantile(0.25)
# Out:
# Id               63.250
# SepalLengthCm     5.600
# SepalWidthCm      2.525
# PetalLengthCm     4.000
# PetalWidthCm      1.200
# Name: 0.25, dtype: float64

# %%
iris_versicolor.quantile(0.31)
# Out:
# Id               66.190
# SepalLengthCm     5.619
# SepalWidthCm      2.619
# PetalLengthCm     4.019
# PetalWidthCm      1.300
# Name: 0.31, dtype: float64

# %%
nba=pd.read_csv('nba.csv')

# %%
nba.shape
# Out:
# (457, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
nba["College"] = nba["College"].fillna(nba["College"].mode()[0])
nba["Salary"]=nba["Salary"].fillna(nba["Salary"].mean())

# %%
nba.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
weight=nba.groupby('Weight')

# %%
weight.describe()
# Out:
#        Number                                                   Age        \
#         count  mean       std   min    25%   50%    75%   max count  mean
# Weight
# 161.0     1.0   0.0       NaN   0.0   0.00   0.0   0.00   0.0   1.0  31.0
# 165.0     2.0  10.0  2.828427   8.0   9.00  10.0  11.00  12.0   2.0  23.0
# 169.0     1.0  55.0       NaN  55.0  55.00  55.0  55.00  55.0   1.0  26.0
# 170.0     1.0   2.0       NaN   2.0   2.00   2.0   2.00   2.0   1.0  25.0
# 172.0     2.0  19.5  3.535534  17.0  18.25  19.5  20.75  22.0   2.0  29.0
# ...       ...   ...       ...   ...    ...   ...    ...   ...   ...   ...
# 279.0     1.0   0.0       NaN   0.0   0.00   0.0   0.00   0.0   1.0  22.0
# 280.0     1.0  23.0       NaN  23.0  23.00  23.0  23.00  23.0   1.0  21.0
# 289.0     1.0  25.0       NaN  25.0  25.00  25.0  25.00  25.0   1.0  31.0
# 290.0     1.0  40.0       NaN  40.0  40.00  40.0  40.00  40.0   1.0  27.0
# 307.0     1.0  14.0       NaN  14.0  14.00  14.0  14.00  14.0   1.0  30.0
# ...

# %%
team=nba.groupby("Team")

# %%
team.head()
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 442   Trevor Booker       Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke       Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445      Dante Exum       Utah Jazz    11.0       PG  20.0    6-6   190.0
# 446  Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
team.describe()
# Out:
#                        Number                                                 \
#                         count       mean        std  min    25%   50%    75%
# Team
# Atlanta Hawks            15.0  19.000000  11.476684  0.0  11.50  17.0  25.50
# Boston Celtics           15.0  31.866667  30.300558  0.0   9.50  28.0  42.50
# Brooklyn Nets            15.0  18.266667  14.104035  0.0   8.00  15.0  27.00
# Charlotte Hornets        15.0  17.133333  16.672761  0.0   4.00  12.0  27.50
# Chicago Bulls            15.0  19.200000  17.193022  0.0   5.50  16.0  28.00
# Cleveland Cavaliers      15.0  14.466667  13.809245  0.0   4.50  12.0  21.50
# Dallas Mavericks         15.0  20.000000  16.252472  1.0   6.00  21.0  30.50
# Denver Nuggets           15.0  15.266667  19.655849  0.0   4.00   9.0  18.00
# Detroit Pistons          15.0  17.266667  15.303906  0.0   5.50  13.0  23.50
# Golden State Warriors    15.0  20.866667  11.413442  4.0  11.50  20.0  30.50
# ...

# %%
team["Salary"].describe()
# Out:
#                         count          mean           std        min  \
# Team
# Atlanta Hawks            15.0  4.860197e+06  5.194508e+06   525093.0
# Boston Celtics           15.0  4.225583e+06  3.036396e+06  1148640.0
# Brooklyn Nets            15.0  3.501898e+06  5.317817e+06   134215.0
# Charlotte Hornets        15.0  5.222728e+06  4.538601e+06   189455.0
# Chicago Bulls            15.0  5.785559e+06  6.251088e+06   525093.0
# Cleveland Cavaliers      15.0  7.455425e+06  7.484116e+06   111196.0
# Dallas Mavericks         15.0  4.746582e+06  5.030279e+06   525093.0
# Denver Nuggets           15.0  4.330974e+06  4.165468e+06   258489.0
# Detroit Pistons          15.0  4.477884e+06  4.668478e+06   111444.0
# Golden State Warriors    15.0  5.924600e+06  5.664282e+06   289755.0
# Houston Rockets          15.0  5.018868e+06  6.414749e+06   200600.0
# Indiana Pacers           15.0  4.450122e+06  4.584514e+06   211744.0
# ...

# %%
team["Salary"].sum()
# Out:
# Team
# Atlanta Hawks             7.290295e+07
# Boston Celtics            6.338375e+07
# Brooklyn Nets             5.252848e+07
# Charlotte Hornets         7.834092e+07
# Chicago Bulls             8.678338e+07
# Cleveland Cavaliers       1.118314e+08
# Dallas Mavericks          7.119873e+07
# Denver Nuggets            6.496461e+07
# Detroit Pistons           6.716826e+07
# Golden State Warriors     8.886900e+07
# Houston Rockets           7.528302e+07
# Indiana Pacers            6.675183e+07
# Los Angeles Clippers      9.485464e+07
# Los Angeles Lakers        7.177043e+07
# Memphis Grizzlies         9.592162e+07
# Miami Heat                9.220104e+07
# Milwaukee Bucks           6.960352e+07
# Minnesota Timberwolves    6.455238e+07
# New Orleans Pelicans      8.275077e+07
# New York Knicks           7.330390e+07
# Oklahoma City Thunder     9.376530e+07
# Orlando Magic             6.016147e+07
# Philadelphia 76ers        3.583558e+07
# Phoenix Suns              6.344514e+07
# ...

# %%
team["Salary"].max()
# Out:
# Team
# Atlanta Hawks             18671659.0
# Boston Celtics            12000000.0
# Brooklyn Nets             19689000.0
# Charlotte Hornets         13500000.0
# Chicago Bulls             20093064.0
# Cleveland Cavaliers       22970500.0
# Dallas Mavericks          16407500.0
# Denver Nuggets            14000000.0
# Detroit Pistons           16000000.0
# Golden State Warriors     15501000.0
# Houston Rockets           22359364.0
# Indiana Pacers            17120106.0
# Los Angeles Clippers      21468695.0
# Los Angeles Lakers        25000000.0
# Memphis Grizzlies         19688000.0
# Miami Heat                22192730.0
# Milwaukee Bucks           16407500.0
# Minnesota Timberwolves    12700000.0
# New Orleans Pelicans      15514031.0
# New York Knicks           22875000.0
# Oklahoma City Thunder     20158622.0
# Orlando Magic             11250000.0
# Philadelphia 76ers         6500000.0
# Phoenix Suns              13500000.0
# Portland Trail Blazers     8042895.0
# ...

# %%
nba['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
nba["Age"].min()
# Out:
# 19.0

# %%
nba["Age"].max()
# Out:
# 40.0

# %%
bins = [19, 25, 31, 36, 40]
labels = ["Young adults", "Early adults", "Mid adults", "Mature adults"]

nba["AgeGroup"] = pd.cut(nba["Age"], bins=bins, labels=labels)

# %%
nba["AgeGroup"]
# Out:
# 0      Young adults
# 1      Young adults
# 2      Early adults
# 3      Young adults
# 4      Early adults
#            ...
# 452    Young adults
# 453    Early adults
# 454    Young adults
# 455    Early adults
# 456    Early adults
# Name: AgeGroup, Length: 457, dtype: category
# Categories (4, object): ['Young adults' < 'Early adults' < 'Mid adults' < 'Mature adults']

# %%
nba["AgeGroup"].value_counts()
# Out:
# AgeGroup
# Young adults     197
# Early adults     189
# Mid adults        56
# Mature adults     13
# Name: count, dtype: int64
